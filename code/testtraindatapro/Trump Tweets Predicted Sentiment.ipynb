# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import Table, Column, Integer, String, Float, DateTime, MetaData

# %%
engine = create_engine("sqlite:///../../data/data.sqlite", echo=False)
conn = engine.connect()

Base = automap_base()
Base.prepare(engine, reflect=True)
meta = MetaData()

# %%
tweets_text_data = pd.read_sql('SELECT * FROM TWEETS', conn)
tweets_text_data.head()
# Out:
#                 source                                               text  \
# 0  Twitter for Android        "@flicka__: @realDonaldTrump for president"
# 1  Twitter for Android  The Mar-a-Lago Club was amazing tonight. Every...
# 2  Twitter for Android  "@archangeljf12:  ;,@realDonaldTrump for Presi...
# 3  Twitter for Android  "@TalentlessCook: @realDonaldTrump You're only...
# 4  Twitter for Android  "@yankeejayman: @realDonaldTrump @flicka__ Do ...
#
#                    created_at  retweet_count  favorite_count  \
# 0  2015-01-01 06:54:59.000000             18              58
# 1  2015-01-01 07:02:39.000000             27              77
# 2  2015-01-01 07:04:33.000000             24              56
# 3  2015-01-01 07:04:45.000000             17              56
# 4  2015-01-01 07:05:27.000000             11              38
#
#                id_str
# 0  550545703932796928
# 1  550547634218614784
# 2  550548111161294848
# 3  550548164177309696
# 4  550548339708940288

# %%
import pickle
filename = 'finalized_model.sav'

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
#tokenizer to remove unwanted elements from out data like symbols and numbers
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(lowercase=True,stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize,max_features=30495)
text_counts= cv.fit_transform(tweets_text_data['text'])
text_counts
# Out:
# <23645x30495 sparse matrix of type '<class 'numpy.int64'>'
# 	with 299049 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf=TfidfVectorizer()
text_tf= tf.fit_transform(tweets_text_data['text'])
text_tf
# Out:
# <23645x30845 sparse matrix of type '<class 'numpy.float64'>'
# 	with 472198 stored elements in Compressed Sparse Row format>

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.predict(text_counts)
print(len(result))
# Out:
# 23645

# %%
len(tweets_text_data)
# Out:
# 23645

# %%
tweets_text_data['sentiment']=result
tweets_text_data['sentiment']= tweets_text_data['sentiment'].replace(0,"Negative").replace(4,"Positive")

# %%
pd.set_option('display.max_colwidth', -1)
tweets_text_data.head(20)
# Out:
#                  source  \
# 0   Twitter for Android
# 1   Twitter for Android
# 2   Twitter for Android
# 3   Twitter for Android
# 4   Twitter for Android
# 5   Twitter for Android
# 6   Twitter for Android
# 7   Twitter for Android
# 8   Twitter for Android
# 9   Twitter for Android
# 10  Twitter for Android
# 11  Twitter for Android
# 12  Twitter for Android
# 13  Twitter for Android
# 14  Twitter for Android
# 15  Twitter for Android
# 16  Twitter for Android
# 17  Twitter for Android
# 18  Twitter for Android
# 19  Twitter for Android
#
#                                                                                                                                             text  \
# 0   "@flicka__: @realDonaldTrump for president"
# 1   The Mar-a-Lago Club was amazing tonight. Everybody was there, the biggest and the hottest. Palm Beach is so lucky to have best club in world
# 2   "@archangeljf12:  ;,@realDonaldTrump for President of the United States! @SenTedCruz Vice President ;A #WinningTicket2016 #TrumpCruz2016"
# 3   "@TalentlessCook: @realDonaldTrump You're only a year away from #2016 ...pick a running mate. Happy New Year"
# 4   "@yankeejayman: @realDonaldTrump @flicka__ Do u ever sleep?"  Not much!
# 5   "@JoshHammer77: @realDonaldTrump happy new year sir can't wait for #CelebrityApprentice"
# 6   "@SparkleAWin: @realDonaldTrump So excited for a New Year &amp; new Celeb Apprentice! Can't wait to see The Trumps back in The Boardroom!"
# 7   "@Danwolff22: @realDonaldTrump I believe in you to bring this country back to what it once was! MR. Trump for president!" Thanks Dan!
# 8   "@tlowery19: @realDonaldTrump for president please! 😩"
# 9   "@jmcafee23: @realDonaldTrump please run for president this country needs you!"
# 10  "@archangeljf12: @realDonaldTrump Palm Beach is one of the greatest places in the World to Live!  #TrumpPOTUS2016 #HappyNewYear
# 11  "@SaraPattersonn: @realDonaldTrump hey be president"
# 12  "@ericleebow: @realDonaldTrump Hope you finally run for President. That should be your new year's resolution." Good thought!
# 13  "@Felix_Whiskas: If you're interested in 'balancing' work and pleasure, stop! Instead make your work more pleasurable - @realDonaldTrump"
# 14  "@samanthajrose: @realDonaldTrump #Trumpfan #TrumpForPresident"
# 15  "@iintend: DonaldTrump At one time you were 900 million in debt and you came back. You never flinched. You have to respect that."  Thank you
# 16  "@MarkFleming22: “If you're interested in 'balancing' work and pleasure, stop! Instead make your work more pleasurable - @realDonaldTrump"”"
# 17  "@seankesser: @LoreleiJP @realDonaldTrump @VeryOddDog Trump himself never ever filed for bankruptcy" So true, thank you!
# 18  "@AlphaQuintesson: @realDonaldTrump please run for president you got my vote 💦🍑"
# 19  "@KdanielsK: @misstcassidy @AllAboutTheTea_ I definitely think Kenya is smarter than Brandi, but Kenya doesn't play well w/ others."
#
#                     created_at  retweet_count  favorite_count  \
# 0   2015-01-01 06:54:59.000000  18             58
# 1   2015-01-01 07:02:39.000000  27             77
# 2   2015-01-01 07:04:33.000000  24             56
# 3   2015-01-01 07:04:45.000000  17             56
# 4   2015-01-01 07:05:27.000000  11             38
# 5   2015-01-01 07:06:13.000000  9              30
# 6   2015-01-01 07:08:39.000000  9              33
# 7   2015-01-01 07:09:11.000000  15             42
# 8   2015-01-01 07:09:22.000000  10             54
# 9   2015-01-01 07:09:30.000000  17             58
# 10  2015-01-01 07:10:05.000000  9              48
# 11  2015-01-01 07:10:50.000000  19             69
# 12  2015-01-01 07:11:21.000000  17             73
# 13  2015-01-01 12:30:51.000000  92             159
# 14  2015-01-02 02:56:03.000000  19             43
# 15  2015-01-02 02:59:42.000000  39             116
# 16  2015-01-02 03:01:55.000000  66             104
# 17  2015-01-02 03:02:36.000000  13             41
# 18  2015-01-02 03:02:53.000000  1887           1795
# 19  2015-01-02 21:30:04.000000  6              24
#
#                 id_str sentiment
# 0   550545703932796928  Negative
# 1   550547634218614784  Negative
# 2   550548111161294848  Positive
# 3   550548164177309696  Negative
# 4   550548339708940288  Negative
# 5   550548532600766464  Positive
# 6   550549145027870720  Positive
# 7   550549278679379968  Positive
# 8   550549323562639360  Positive
# 9   550549358819934208  Negative
# 10  550549504718802944  Negative
# 11  550549694691430400  Positive
# 12  550549822919704576  Negative
# 13  550630228599791616  Positive
# 14  550847964898660352  Positive
# 15  550848883493179392  Negative
# 16  550849439754383360  Positive
# 17  550849612614213632  Positive
# 18  550849683724447744  Negative
# 19  551128313281118208  Positive

# %%
new_df = tweets_text_data.drop(columns=["source","text","created_at","retweet_count","favorite_count"])

# %%
new_df.head()
# Out:
#                id_str sentiment
# 0  550545703932796928  Negative
# 1  550547634218614784  Negative
# 2  550548111161294848  Positive
# 3  550548164177309696  Negative
# 4  550548339708940288  Negative

# %%
sentiment = Table(
   'sentiment', meta, 
    Column('id_str', Integer, primary_key = True),
    Column('sentiment',String)
)

# %%
meta.bind = engine
meta.drop_all()
meta.create_all()

# %%
new_df.to_sql('sentiment', conn, if_exists='append', index=False, index_label="id_str")

# %%
tweets_text_data.to_csv("SentimentData.csv",index=False)
