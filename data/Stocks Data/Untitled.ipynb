# %%
import pandas as pd

# %%
ijr = pd.read_csv("IJR.csv")
mdy = pd.read_csv("MDY.csv")
spy = pd.read_csv("spy.csv")

# %%
ijr.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2015-01-02  57.255001  57.445000  56.060001  56.610001  52.813873  4261200
# 1  2015-01-05  56.230000  56.430000  55.500000  55.744999  52.006870  3445400
# 2  2015-01-06  55.875000  55.900002  54.410000  54.814999  51.139244  5321000
# 3  2015-01-07  55.299999  55.384998  54.860001  55.384998  51.671017  3437000
# 4  2015-01-08  55.740002  56.410000  55.740002  56.355000  52.575966  2663400

# %%
mdy.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-01-02  265.279999  265.829987  261.670013  263.549988  246.707321
# 1  2015-01-05  261.899994  262.899994  258.980011  259.649994  243.056564
# 2  2015-01-06  259.959991  260.309998  255.320007  256.609985  240.210892
# 3  2015-01-07  258.720001  260.209991  257.700012  260.079987  243.459091
# 4  2015-01-08  261.910004  264.420013  261.890015  264.109985  247.231613
#
#     Volume
# 0  1532700
# 1  1108500
# 2  2167800
# 3  1278800
# 4  3690500

# %%
spy.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-01-02  206.380005  206.880005  204.179993  205.429993  186.159332
# 1  2015-01-05  204.169998  204.369995  201.350006  201.720001  182.797379
# 2  2015-01-06  202.089996  202.720001  198.860001  199.820007  181.075607
# 3  2015-01-07  201.419998  202.720001  200.880005  202.309998  183.332016
# 4  2015-01-08  204.009995  206.160004  203.990005  205.899994  186.585236
#
#       Volume
# 0  121465900
# 1  169632600
# 2  209151400
# 3  125346700
# 4  147217800

# %%
ijr["change"] = ijr.Close - ijr.Open
mdy["change"] = mdy.Close - mdy.Open
spy["change"] = spy.Close - spy.Open

# %%
ijr.rename(columns={"Date":"date", "Open":"open", "High":"high", "Low":"low", "Close":"close", "Adj Close":"adj_close", "Volume":"volume"})
mdy.rename(columns={"Date":"date", "Open":"open", "High":"high", "Low":"low", "Close":"close", "Adj Close":"adj_close", "Volume":"volume"})
spy.rename(columns={"Date":"date", "Open":"open", "High":"high", "Low":"low", "Close":"close", "Adj Close":"adj_close", "Volume":"volume"})
# Out:
#             date        open        high         low       close   adj_close  \
# 0     2015-01-02  206.380005  206.880005  204.179993  205.429993  186.159332
# 1     2015-01-05  204.169998  204.369995  201.350006  201.720001  182.797379
# 2     2015-01-06  202.089996  202.720001  198.860001  199.820007  181.075607
# 3     2015-01-07  201.419998  202.720001  200.880005  202.309998  183.332016
# 4     2015-01-08  204.009995  206.160004  203.990005  205.899994  186.585236
# ...          ...         ...         ...         ...         ...         ...
# 1245  2019-12-12  314.429993  317.989990  314.170013  317.130005  315.578461
# 1246  2019-12-13  316.869995  318.670013  316.019989  317.320007  315.767517
# 1247  2019-12-16  319.220001  320.149994  317.250000  319.500000  317.936859
# 1248  2019-12-17  319.920013  320.250000  319.480011  319.570007  318.006531
# 1249  2019-12-18  320.000000  320.250000  319.529999  319.589996  318.026398
#
#          volume    change
# ...

# %%
ijr.to_csv("cleaned_ijr.csv")
mdy.to_csv("cleaned_mdy.csv")
spy.to_csv("cleaned_spy.csv")
